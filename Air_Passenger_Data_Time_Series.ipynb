# %%
# Performed as a part of curriculum at Great Learning
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

df1=pd.read_csv("/content/sample_data/AirPassengers.csv")
df1.dtypes
# Out:
# Month          object
# #Passengers     int64
# dtype: object

# %%
df1.head()
# Out:
#      Month  #Passengers
# 0  1949-01          112
# 1  1949-02          118
# 2  1949-03          132
# 3  1949-04          129
# 4  1949-05          121

# %%
df1=pd.read_csv("/content/sample_data/AirPassengers.csv",parse_dates=["Month"])
df1.head()
# Out:
#        Month  #Passengers
# 0 1949-01-01          112
# 1 1949-02-01          118
# 2 1949-03-01          132
# 3 1949-04-01          129
# 4 1949-05-01          121

# %%
df1.dtypes
# Out:
# Month          datetime64[ns]
# #Passengers             int64
# dtype: object

# %%
df1=pd.read_csv("/content/sample_data/AirPassengers.csv",parse_dates=["Month"],index_col="Month")
df1.head()
# Out:
#             #Passengers
# Month
# 1949-01-01          112
# 1949-02-01          118
# 1949-03-01          132
# 1949-04-01          129
# 1949-05-01          121

# %%
df1['1951-04-01':'1952-03-01']
# Out:
#             #Passengers
# Month
# 1951-04-01          163
# 1951-05-01          172
# 1951-06-01          178
# 1951-07-01          199
# 1951-08-01          199
# 1951-09-01          184
# 1951-10-01          162
# 1951-11-01          146
# 1951-12-01          166
# 1952-01-01          171
# 1952-02-01          180
# 1952-03-01          193

# %%
from pylab import rcParams
rcParams['figure.figsize']=12,8
df1.plot()

# %%
df1_mul_decompose=seasonal_decompose(df1,model="multiplicative")
df1_mul_decompose.plot()

# %%
df1_log=df1.copy()

# %%
df1_log['#Passengers']=np.log(df1)

# %%
df1_log['#Passengers']
# Out:
# Month
# 1949-01-01    4.718499
# 1949-02-01    4.770685
# 1949-03-01    4.882802
# 1949-04-01    4.859812
# 1949-05-01    4.795791
#                 ...
# 1960-08-01    6.406880
# 1960-09-01    6.230481
# 1960-10-01    6.133398
# 1960-11-01    5.966147
# 1960-12-01    6.068426
# Name: #Passengers, Length: 144, dtype: float64

# %%
df1_log.plot()

# %%
# Comparing with the original series
plt.subplot(2,1,1)
plt.title('Original Time Series')
plt.plot(df1)

plt.subplot(2,1,2)
plt.title('Log Transformed Time Series')
plt.plot(df1_log)
plt.tight_layout()
